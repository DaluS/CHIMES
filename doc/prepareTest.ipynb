# %% [markdown]
# Unit tests preparation

# %%
#%reload_ext autoreload
#%autoreload 2

# Importing the main library #################
import sys
path = "C:\\Users\\Paul Valcke\\Documents\\GitHub\\GEMMES"
sys.path.insert(0, path )

import pygemmes as chm
from IPython.display import display,HTML,Markdown

import pandasgui
from pandasgui import show
# Out:
# CHIMES:
# Core for Holistic Intertwined Models of Ecological Sustainability
#
# * Version 0.1
# * Last update 2023/08/10
# * Developped at the environmental justice program https://environmentaljustice.georgetown.edu/#
# * Contact : Paul Valcke pv229@georgetown.edu
#
# Welcome in CHIMES, a modular library to prototype and study dynamical systems !
# This library is oriented toward generation of macroeconomic complexity models for ecological sustainability
#
# If you find bugs, want some new extensions, or help us improve the library, please create a new issue on github
# If this is the first time you open this library, please look at the tutorial file in doc/tutorial.py or better, and execute it line by line.
#
# The ipythonNotebook is at : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\doc\TUTORIALS\TUTORIAL.ipynb
# If you want to customize pyIDEE (advancer users) like removing this message, edit : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\_config.py

# %% [markdown]
# ## CHM Content

# %%
for FULL in [False,True]:
    for Return in [dict,list,False]: 
        out = chm.get_available_models(FULL=FULL,Return=Return)

for model in chm.get_available_models(Return=list):
    for returnString in [True,False]:
        chm.get_model_documentation(model,returnString=returnString)

chm.get_available_fields(exploreModels=True)
chm.get_available_fields(exploreModels=False)

chm.get_available_plots()

chm.get_available_functions()

chm.get_available_operators()

# %%
hub=chm.Hub('GK')

# %%
modelist = chm.get_available_models(Return=dict)
for model in modelist.keys():
    for preset in [None]+modelist[model].get('Preset',[]):
        #try: 
        #print(model)
        #hub=chm.Hub(model,verb=False)
        hub.run(NstepsInput=10,verb=False)
        if (preset is not None and '__' in model):
            print(model,preset)
            hub.plot_preset() 
        #except BaseException as E:
        #    print(f'{model} + {preset}  not working \n {E}')
# Out:
# __TEMPLATE__ preset0
# C:\Users\Paul Valcke\Documents\GitHub\GEMMES\models\ReducedSystem\_model_reduced_GK.py:38: RuntimeWarning: overflow encountered in exp
#   'kappa': {'func': lambda k0, k1, k2, pi: k0 + k1 * np.exp(k2 * pi),
# C:\Users\Paul Valcke\Documents\GitHub\GEMMES\models\ReducedSystem\_model_reduced_GK.py:30: RuntimeWarning: invalid value encountered in multiply
#   'd': {         'func': lambda d, kappa, pi, g, inflation,Delta:  kappa - pi + pi*Delta  - d*(g+inflation),}
# C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\_utilities\_solvers.py:105: RuntimeWarning: invalid value encountered in add
#   yend =  {k: y[k]+(  dy1_on_dt[k]

# %%
import matplotlib.pyplot as plt

hub=chm.Hub('GK')
hub.set_dparam(**{'Tmax':100,'dt':0.1})
hub.run()
hub.reinterpolate_dparam(100)
### One var 
chm.plots.Var(hub,**{'key':'employment', 
        'mode':False, 
        'log':False,
        'idx':0, 
        'Region':0, 
        'tini':False, 
        'tend':False, 
        'title':''})
plt.close('all')
chm.plots.Var(hub,**{'key':'employment',
        'mode':'sensitivity',  #
        'log':False,
        'idx':0, 
        'Region':0, 
        'tini':False, 
        'tend':False, 
        'title':''})
plt.close('all')
chm.plots.Var(hub,**{'key':'employment',
        'mode':'sensitivity', 
        'log':True, #
        'idx':0, 
        'Region':0, 
        'tini':False, 
        'tend':False, 
        'title':''})
plt.close('all')
chm.plots.Var(hub,**{'key':'employment',
        'mode':'cycles', #
        'log':False,
        'idx':0, 
        'Region':0, 
        'tini':False, 
        'tend':False, 
        'title':''})
plt.close('all')
chm.plots.Var(hub,**{'key':'employment',
        'mode':False, 
        'log':False,
        'idx':0, 
        'Region':0, 
        'tini':10, #
        'tend':20, #
        'title':''})
plt.close('all')
chm.plots.Var(hub,**{'key':'employment',
        'mode':False, 
        'log':False,
        'idx':0, 
        'Region':0, 
        'tini':10, #
        'tend':20, #
        'title':'Hello'})
plt.close('all')

chm.plots.cycles_characteristics(hub,**{'xaxis':'omega', 
                                        'yaxis':'employment', 
                                        'ref':'employment', 
                                        'type1':'frequency', 
                                        'normalize':False, 
                                        'Region':0, 
                                        'title':''})
plt.close('all')
chm.plots.plotbyunits(hub,**{'filters_key':(),
                        'filters_units':(),
                        'filters_sector':(),
                        'separate_variables':{}, 
                        'lw':1, 
                        'idx':0, 
                        'Region':0, 
                        'tini':False, 
                        'tend':False, 
                        'title':''})
plt.close('all')
chm.plots.plotbyunits(hub,**{'filters_key':(),
                        'filters_units':(),
                        'filters_sector':(),
                        'separate_variables':{}, 
                        'lw':1, 
                        'idx':0, 
                        'Region':0, 
                        'tini':10, 
                        'tend':15, 
                        'title':''})
plt.close('all')
chm.plots.plotbyunits(hub,**{'filters_key':('pi','Pi'),
                        'filters_units':('y^{-1}'),
                        'filters_sector':(),
                        'separate_variables':{'':['omega']}, 
                        'lw':1, 
                        'idx':0, 
                        'Region':0, 
                        'tini':10, 
                        'tend':15, 
                        'title':''})
plt.close('all')
chm.plots.plotnyaxis(hub,**{'y':[['pi','omega'],['d']],
                                'x':'time', 
                                'idx':0,
                                'Region':0,
                                'log':False,# []
                                'title':'', 
                                })
plt.close('all')
chm.plots.plotnyaxis(hub,**{'y':[['omega'],['employment']],
                                'x':'time', 
                                'idx':0,
                                'Region':0,
                                'log':True,
                                'title':'', 
                                })
plt.close('all')
chm.plots.plotnyaxis(hub,**{   'y':[['omega'],['employment']],
                                'x':'time', 
                                'idx':0,
                                'Region':0,
                                'log':[True,False],
                                'title':'', 
                                })
plt.close('all')

chm.plots.XY (hub,**{    'x':'employment',
                        'y':'omega',
                        'color':'d', 
                        'scaled':True,
                        'idx':0, 
                        'Region':0, 
                        'tini':False, 
                        'tend':False, 
                        'title':'', 
                        })
plt.close('all')
chm.plots.XY (hub,**{    'x':'employment',
                        'y':'omega',
                        'color':'d', 
                        'scaled':False,
                        'idx':0, 
                        'Region':0, 
                        'tini':False, 
                        'tend':False, 
                        'title':'', 
                        })
plt.close('all')
chm.plots.XY (hub,**{    'x':'employment',
                        'y':'omega',
                        'color':'d', 
                        'scaled':False,
                        'idx':0, 
                        'Region':0, 
                        'tini':10, 
                        'tend':15, 
                        'title':'', 
                        })
plt.close('all')
chm.plots.XYZ(hub,**{   'x':'employment',
                        'y':'omega',
                        'z':'d', 
                        'color':'time', 
                        'idx':0, 
                        'Region':0, 
                        'tini':False, 
                        'tend':False, 
                        'title':''},)
plt.close('all')
chm.plots.XYZ(hub,**{   'x':'employment',
                        'y':'omega',
                        'z':'d', 
                        'color':'time', 
                        'idx':0, 
                        'Region':0, 
                        'tini':10, 
                        'tend':20, 
                        'title':''},)
plt.close('all')

chm.plots.plotbyunits(hub,**{'filters_key' :('p'),
                                'filters_units':('Units'),
                                'filters_sector':(),
                                'separate_variables':{'':['employment','omega']},
                                'idx':0,
                                'Region':0,
                                'title':'',
                                'lw':2})
plt.close('all')

#chm.plots.cycles_characteristics(hub,**{})

chm.plots.plotnyaxis(hub,**{'x': 'time',
                                'y': [['employment', 'employment'],
                                        ['omega'],
                                        ],
                                'idx':0,
                                'title':'',
                                'lw':1})
plt.close('all')



hub=chm.Hub('CHIMES0')
chm.plots.Sankey(hub)

R=hub.get_dparam()
for sector in R['Nprod']['list'] :
        chm.plots.plotnyaxis(hub, y=[[['inflation', sector],
                                ['inflationMarkup', sector],
                                ['inflationdotV', sector], ],
                                [['dotV',sector]],
                                [['c',sector],
                                ['p',sector]],
                                [['pi',sector],
                                ['kappa',sector]],
                                [['employment',sector],
                                ['u',sector],
                                ]],)
        chm.plots.repartition(hub,
                        ['pi','omega','Mxi','Mgamma','rd','reloverinvest','reldotv'],
                        sign= [1,1,1,1,1,1,-1],
                        sector=sector,
                        title=f'Expected relative budget $\pi$ for sector {sector}')
        chm.plots.repartition(hub,['Minter','Minvest','C','dotV'],
                        ref='Y',
                        sector=sector,
                        title=f'Physical Fluxes for sector {sector}')
        chm.plots.repartition(hub,['MtransactY','MtransactI','wL','pC','rD'],
                        sign=[1, 1, 1, -1, 1],
                        ref='dotD',
                        sector=sector,
                        title=f'Monetary Fluxes for sector {sector}',
                        removetranspose=True)
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'philinConst', 'philinSlope']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['d', 'g', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'inflation', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
#
# Changes Ignored:['Tmax', 'dt']
#
# time step 1000 / 1000
# the system is calculating statsensitivity...
# done
# Calculation of cycles on each field as ref...
# done
# The following fields are defined in the model but not it the library :
# 	- statevar: ['deltaK', 'gK']
# The following fields are identified as parameters :
# 	- independant : ['delta', 'gammai', 'sigma', 'alpha', 'n', 'z', 'b', 'nu0', 'Gamma', 'Xi', 'eta', 'mu0', 'chi', 'Cpond', 'r', 'philinConst', 'philinSlope', 'k0']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : ['deltaK', 'Minter', 'Minvest', 'rDh', 'rd', 'gK', 'ROC', 'gamma', 'xi', 'reldotv', 'reloverinvest']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['w', 'u', 'nu', 'Mgamma', 'Mxi', 'Y', 'deltaK', 'Minter', 'MtransactY', 'rD', 'rDh', 'rd', 'gamma', 'xi', 'a', 'omega', 'c', 'inflationMarkup', 'L', 'wL', 'W', 'pi', 'ROC', 'employment', 'C', 'pC', 'employmentAGG', 'Phillips', 'kappa', 'reloverinvest', 'basket', 'I', 'Ir', 'dotV', 'Minvest', 'MtransactI', 'dotD', 'gK', 'reldotv', 'inflationdotV', 'inflation', 'ibasket']
# 	- differential: ['D', 'Dh', 'V', 'K', 'p', 'w0', 'u0', 'a0', 'N', 'time']
# NO RUN DONE YET, SYSTEM IS DOING A RUN WITH GIVEN FIELDS
# C:\Users\Paul Valcke\Documents\GitHub\GEMMES\models\Core\_model_CHIMES0.py:81: RuntimeWarning:
#
# invalid value encountered in log
# time step 1000 / 1000

# %% [markdown]
# Small calls

# %%
dargs = hub.dargs
dfunc_order = hub.dfunc_order
dmisc = hub.dmisc
dmodel = hub.dmodel
dparam = hub.dparam
supplements = hub.supplements
hub

# %%
show(hub.get_fieldsproperties())

# %%
hub.get_equations_description()

# %%
hub.get_summary()

# %%
#hub.run()
hub.run(   NtimeOutput=False,
           NstepsInput=10000,)
#hub.run(verb)
#hub.get_summary()

# %%
hub.reset()
hub.get_summary()

# %%
hub=chm.Hub('GK')
hub.run()
show(**hub.get_new_summary())

# %%
hub.get_Network()

# %%
#hub.calculate_ConvergeRate
#hub.calculate_Cycles
#hub.calculate_StatSensitivity
#hub.Extract_preset

#hub.get_dparam_as_reverse_dict

# %%
hub.reverse_cycles_dic
hub.run
hub.get_new_summary
hub.get_presets
hub.get_summary
hub.plot
hub.plot_preset
hub.reinterpolate_dparam
hub.reverse_cycles_dic
hub.reset
hub.set_dparam
hub.set_dpreset
hub.set_preset

# %%
chm.generate_dic_distribution()
chm.plots.convergence
chm.plots.cycles_characteristics
chm.plots.phasespace
chm.plots.plot3D
chm.plots.plotbyunits
chm.plots.plotnyaxis
chm.plots.repartition
chm.plots.Sankey
chm.plots.Var
chm.plots.XY
chm.plots.XYZ

# %%
chm.get_available_models()

# %%
hub=chm.Hub('GK')
dpreset = {'test': {'fields': {'philinConst': -0.55465958},
                    'com': '',
                    'plots': {}},}
hub.set_dpreset(dpreset,preset='test')

hub=chm.Hub('GK')
hub.set_preset('default')

# Monosectoral 
hub=chm.Hub('GK',verb=False); hub.set_dparam('a',1           ,verb=False)
hub=chm.Hub('GK',verb=False); hub.set_dparam('alpha',0.01    ,verb=False)  
hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'alpha':0.01},verb=False)      

# Dimensions nr and nx 
hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'Tmax':10,
                                                'dt':0.01},verb=False)
hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nx':10,
                                                'nr':5},verb=False)
hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nx':['one','two'],
                                                'nr':['here','there','test']},verb=False)

try:
# Multiple values 
    hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nx':3,
                                                    'alpha':[0.01,0.02,0.03]})
except BaseException as ERR: print(ERR)
#hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nr':['France','USA'],
#                                                'alpha':[['nr','France'],0.01]})    
try:hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nr':['France','USA'],
                                                'nx': 3,    
                                                'alpha':[['nr','France'],['nx',1],0.01]})
except BaseException as ERR: print(ERR)
try:hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nr':['France','USA'],
                                                'nx': 6,    
                                                'alpha':[['nr',0],['nx',0,4],[0.5,0.2]]}) 
except BaseException as ERR: print(ERR)
try:hub=chm.Hub('GK',verb=False); hub.set_dparam(**{'nr':['France','USA'],
                                                'nx': 6, 
                                                'alpha':{'nr':['France','USA'],
                                                            'nx':1,
                                                            'value':0.5}})
except BaseException as ERR: print(ERR)
# Multisectoral        
try:hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('p',[0.1,1])                      #will put [0,1] for all parrallel all regions
except BaseException as ERR: print(ERR)
#hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('p',[['nr',0],[0.1,1]])            #will put [0,1] for all parrallel in region 0
try:hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('p',[['nr',0,1],[0.1,1]])          #will put [0,1] for all parrallel in region 0 and 1
except BaseException as ERR: print(ERR)
try:hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('p',[['nx',0],['nr',0,1],[0.1,1]]) #will put [0,1] for parrallel system 0, in region 0 and 1
except BaseException as ERR: print(ERR)
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'philinConst', 'philinSlope']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['d', 'g', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'inflation', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
# OVERRIDE presets in dpreset
#
# Changing Fields: ['philinConst']
# Identified philinConst as a value change on all axes
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'philinConst', 'philinSlope']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['d', 'g', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'inflation', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
#
# Changing Dimensions: ['dt']
# Changing Fields: ['alpha', 'n', 'philinConst', 'philinSlope', 'k0', 'k1', 'nu', 'r', 'delta', 'Delta', 'eta', 'a', 'N', 'K', 'D', 'w']
# Changes Ignored:['omega', 'employment', 'debt']
# Identified philinConst as a value change on all axes
# Identified eta as a value change on all axes
# Identified D as a value change on all axes
# Identified r as a value change on all axes
# Identified alpha as a value change on all axes
# Identified Delta as a value change on all axes
# Identified a as a value change on all axes
# Identified N as a value change on all axes
# Identified delta as a value change on all axes
# Identified K as a value change on all axes
# Identified w as a value change on all axes
# Identified philinSlope as a value change on all axes
# Identified nu as a value change on all axes
# Identified n as a value change on all axes
# Identified k1 as a value change on all axes
# Identified k0 as a value change on all axes
#
# Changing Dimensions: ['nx']
# Changing Fields: ['alpha']
# Now nx has 3 sectors with names [0, 1, 2]
#
# Changing Dimensions: ['nr', 'nx']
# Changing Fields: ['alpha']
# Now nr has 2 sectors with names ['France', 'USA']
# Now nx has 3 sectors with names [0, 1, 2]
#
# Changing Dimensions: ['nr', 'nx']
# Changing Fields: ['alpha']
# Now nr has 2 sectors with names ['France', 'USA']
# Now nx has 6 sectors with names [0, 1, 2, 3, 4, 5]
#
# Changing Dimensions: ['nr', 'nx']
# Changing Fields: ['alpha']
# Now nr has 2 sectors with names ['France', 'USA']
# Now nx has 6 sectors with names [0, 1, 2, 3, 4, 5]
# 'Gamma'
# 'Gamma'
# 'Gamma'

# %%
try:hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('Gamma',[[0,1],[1,0]])  #will put [[0,1],[1,0]] for all parrallel all regions
except BaseException as ERR: print(ERR)
try:hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam(**{'Gamma': {'first':['Consumption','Capital'],
                                                                                'second':['Consumption','Consumption'],
                                                                                'nr':0,
                                                                                'value':[0.5,0.22]}})
except BaseException as ERR: print(ERR)
try:hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam(**{'Gamma': {'first':['Consumption','Capital'],
                                                                                'nr':0,
                                                                                'value':[0.5,0.22]}})
except BaseException as ERR: print(ERR)

# %%
hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('p',[0.1,1])
# Out:
# WARNING : projection of sigma on first scalar value. Are you sure about your dimensions ?
# WARNING : projection of chi on first scalar value. Are you sure about your dimensions ?
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 hub=chm.Hub('CHIMES0',preset='Bisectoral',verb=False);hub.set_dparam('p',[0.1,1])
#
# File ~\Documents\GitHub\GEMMES\pygemmes\_core.py:100, in Hub.__init__(self, model, preset, dpresets, verb)
#      98 # update from preset if relevant ######################################
#      99 if dpresets is not None: self.set_dpreset(dpresets,verb=False)
# --> 100 if preset is not None:   self.set_preset(preset, verb=False)
#     101 else:                    self.reset()
#
# File ~\Documents\GitHub\GEMMES\pygemmes\_core.py:155, in Hub.set_preset(self, input, verb)
#     153 else :
#     154     self.__dmodel['preset']=input
# --> 155     self.set_dparam(self,verb=verb,**self.__dmodel['presets'][input]['fields'])
#
# File ~\Documents\GitHub\GEMMES\pygemmes\_core.py:276, in Hub.set_dparam(self, key, value, verb, **kwargs)
#     274 #### SEND IT TO THE PIPE ###################
#     275 self._set_dimensions(verb,**dimtochange)
# --> 276 self._set_fields(verb,**fieldtochange)
#
# File ~\Documents\GitHub\GEMMES\pygemmes\_core.py:390, in Hub._set_fields(self, verb, **kwargs)
#     386 self.__dparam=_class_set.set_shapes_values(self.__dparam,
#     387                                            self.__dmisc['dfunc_order'])
#     388 self.__dargs=_class_set.get_dargs_by_reference(self.__dparam,
#     389                                                dfunc_order=self.__dmisc['dfunc_order'])
# --> 390 self.reset()
#
# File ~\Documents\GitHub\GEMMES\pygemmes\_core.py:793, in Hub.reset(self)
#     791         ERROR+=f'You have a problem on your object sizes for {k0} (shape of kwargs:)\n {[(k,np.shape(v)) for k,v in kwdargs.items()]} \n {Err}\n'
#     792 if len(ERROR):
# --> 793     raise Exception('\n'+ERROR+'ALLOCATION CANNOT BE DONE,CHECK YOUR MODEL FILE !')
#     795 # set run to False
#     796 self.__dmisc['run'] = False
#
# Exception:
# You have a problem on your object sizes for gamma (shape of kwargs:)
#  [('p', (1, 1, 2, 1)), ('Gamma', (1, 1, 1, 1))]
#  matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# You have a problem on your object sizes for xi (shape of kwargs:)
#  [('p', (1, 1, 2, 1)), ('nu', (1, 1, 2, 1)), ('delta', (1, 1, 1, 1)), ('b', (1, 1, 1, 1)), ('Xi', (1, 1, 1, 1))]
#  matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# You have a problem on your object sizes for ROC (shape of kwargs:)
#  [('p', (1, 1, 2, 1)), ('pi', (1, 1, 2, 1)), ('nu', (1, 1, 2, 1)), ('Xi', (1, 1, 1, 1))]
#  matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# You have a problem on your object sizes for Ir (shape of kwargs:)
#  [('p', (1, 1, 2, 1)), ('I', (1, 1, 2, 1)), ('Xi', (1, 1, 1, 1))]
#  matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# You have a problem on your object sizes for dotV (shape of kwargs:)
#  [('Y', (1, 1, 2, 1)), ('Ir', (1, 1, 2, 1)), ('C', (1, 1, 2, 1)), ('Gamma', (1, 1, 1, 1)), ('Xi', (1, 1, 1, 1))]
#  matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# You have a problem on your object sizes for MtransactI (shape of kwargs:)
#  [('p', (1, 1, 2, 1)), ('I', (1, 1, 2, 1)), ('Xi', (1, 1, 1, 1))]
#  matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 2 is different from 1)
# ALLOCATION CANNOT BE DONE,CHECK YOUR MODEL FILE !
