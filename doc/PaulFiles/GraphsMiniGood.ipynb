# %%
import sys 

# Install all dependencies
#!{sys.executable} -m pip install numpy scipy matplotlib pyvis 

# Change path as the folder adress you have put the library in 
path = "C:\\Users\\Paul Valcke\\Documents\\GitHub\\GEMMES" 
sys.path.insert(0, path)
import pygemmes as pgm
# Out:
# pyIDEE
#
# * Version 0.9
# * Last update 2023/01/03
# * Developped at the environmental justice program https://environmentaljustice.georgetown.edu/#
# * Contact : Paul Valcke pv229@georgetown.edu
#
# Welcome in PyIDEE, a modular library to prototype and study dynamical systems !
# This library is oriented toward generation of macroeconomic complexity models
#
# If you find bugs, want some new extensions, or help us improve the library, please create a new issue on github
# If this is the first time you open this library, please look at the tutorial file in doc/tutorial.py or better, and execute it line by line.
#
# The ipythonNotebook is at : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\doc\TUTORIALS\TUTORIAL.ipynb
# If you want to customize pyIDEE (advancer users) like removing this message, edit : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\_config.py

# %%
# %matplotlib widget
hub=pgm.Hub('minigoodwin')
hub.set_dparam(**{'fl':10})
hub.run()
pgm.plots.XYZ(hub,'omega','employment','deltaemploy')
hub.get_summary()
# Out:
# The following fields are defined in the model but not it the library :
# 	- differential: ['employmenteff']
# 	- statevar: ['deltaemploy']
# 	- parameter: ['fl']
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'A', 'philinConst', 'philinSlope']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : ['omega', 'deltaemploy']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Y', 'L', 'phillips', 'omega', 'employment', 'I', 'deltaemploy']
# 	- differential: ['a', 'N', 'K', 'w', 'employmenteff', 'time']
#
# Changing Fields: ['fl']
# Identified fl as a value change on all axes
#
# time step 1000 / 1000
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# ############################################################
# ...

# %%
hub.get_Network(params=True)
# Out:
# Local cdn resources have problems on chrome/safari when used in jupyter-notebook.
# C:\Users\Paul Valcke\Documents\GitHub\GEMMES\doc\minigoodwin.html

# %%
# %%latex
# $$\omega_{eq}  = 1-\Gamma - \Xi\nu\delta - \Xi\nu(1-\Delta)^{-1} (\alpha+n)$$
#
# $$\lambda_{eq} = \phi_1^{-1} f^{-1}(\phi_0 + \alpha(1-\phi^{\alpha}) + (1- \phi^{i}) \textbf{i})$$
#
# $$\Omega_0/\Omega$$
# Out:
# \begin{align}
# \nabla \cdot \vec{\mathbf{E}} & = 4 \pi \rho \\
# \nabla \times \vec{\mathbf{E}}\, +\, \frac1c\, \frac{\partial\vec{\mathbf{B}}}{\partial t} & = \vec{\mathbf{0}} \\
# \nabla \cdot \vec{\mathbf{B}} & = 0
# \end{align}

# %%
# %matplotlib widget
hub=pgm.Hub('CausalModel',preset='default')
hub.set_dparam(**{'Tmax':200,'dt':0.01})
hub.run()
pgm.plots.XYZ(hub,x='omega',y='employment',z='alpha',color='time')
#eq= hub.supplements['get_equilibrium'](hub)
#eq
# Out:
# The following fields are defined in the model but not it the library :
# 	- statevar: ['Yc', 'Lc', 'Leff', 'Cn', 'In', 'flambda', 'productivity', 'Solvability', 'GDPn']
# 	- parameter: ['Phi0', 'Phi1', 'phialpha', 'phii', 'kappaC', 'kappaI', 'zpi']
# The following fields are identified as parameters :
# 	- independant : []
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['Yc', 'Leff', 'nu', 'd', 'productivity', 'g', 'ROC', 'Solvability', 'c', 'mu', 'GDPn', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Yc', 'Lc', 'L', 'employment', 'flambda', 'Solvability', 'Y', 'Leff', 'nu', 'omega', 'd', 'productivity', 'c', 'mu', 'GDPn', 'GDP', 'alpha', 'Pi', 'W', 'Cn', 'In', 'pi', 'ROC', 'I', 'C', 'phillips', 'g']
# 	- differential: ['K', 'V', 'D', 'Dh', 'p', 'a', 'N', 'w', 'time']
#
# Changing Dimensions: ['Tmax', 'dt']
#
# ...

# %%
hub.get_summary()
# Out:
# ############################################################
# ####################      SUMMARY       ####################
# ############################################################
# Model       : CausalModel
# Full Causal model
# File        : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\models\Capital-Human\_model_CausalModel.py
# ####################       Fields       ####################
# statevar        026 ['Yc', 'Lc', 'L', 'employment', 'flambda', 'Solvability', 'Y', 'Leff', 'phillips', 'nu', 'omega', 'd', 'productivity', 'c', 'mu', 'GDPn', 'GDP', 'Pi', 'W', 'Cn', 'In', 'pi', 'ROC', 'I', 'C', 'g']
# differential    009 ['K', 'V', 'D', 'Dh', 'p', 'a', 'N', 'w', 'time']
# parameters      022 ['alpha', 'n', 'r', 'Delta', 'Phi0', 'Phi1', 'phialpha', 'phii', 'inflation', 'delta', 'A', 'Gamma', 'Xi', 'kappaC', 'kappaI', 'Nprod']
# ####################      Presets       ####################
#           default       : Basic
# ...
