# %%
import matplotlib.pyplot as plt 
import numpy as np 

plt.figure('')
omega = np.linspace(0,.99,100)
for eta in [.5,1,2,5,10,100,1000]:
    L = (omega**(-eta/(1+eta)) -1)**(1/eta)
    plt.loglog(omega,L,label='$\eta =$'+str(eta))
plt.legend()
plt.show()
# Out:
# C:\Users\Paul Valcke\AppData\Local\Temp\ipykernel_16336\2103597328.py:7: RuntimeWarning: divide by zero encountered in power
#   L = (omega**(-eta/(1+eta)) -1)**(1/eta)
