# %%
##############################################################
import sys
path = "C:\\Users\\Paul Valcke\\Documents\\GitHub\\GEMMES" 
sys.path.insert(0, path)
import pygemmes as pgm
import numpy as np

from itables import init_notebook_mode
import itables.options as opt
init_notebook_mode(all_interactive=True)
# %matplotlib widget

from IPython.display import display,HTML,Markdown
from IPython.display import IFrame

opt.columnDefs = [{"className": "dt-left", "targets": "_all"}]
opt.classes="display nowrap compact"
opt.scrollY="400px"
opt.scrollCollapse=True
opt.paging=False
##############################################################
# Out:
# pyIDEE
#
# * Version 0.9
# * Last update 2023/01/03
# * Developped at the environmental justice program https://environmentaljustice.georgetown.edu/#
# * Contact : Paul Valcke pv229@georgetown.edu
#
# Welcome in PyIDEE, a modular library to prototype and study dynamical systems !
# This library is oriented toward generation of macroeconomic complexity models
#
# If you find bugs, want some new extensions, or help us improve the library, please create a new issue on github
# If this is the first time you open this library, please look at the tutorial file in doc/tutorial.py or better, and execute it line by line.
#
# The ipythonNotebook is at : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\doc\TUTORIALS\TUTORIAL.ipynb
# If you want to customize pyIDEE (advancer users) like removing this message, edit : C:\Users\Paul Valcke\Documents\GitHub\GEMMES\pygemmes\_config.py
# <script type="module">
#   window.__itables_render = async (table_id, dt_args) => {
#     await initializeDataTables();
#     $(table_id).DataTable(dt_args);
#   };
#
#   async function initializeDataTables() {
#     if ($.prototype.DataTable) {
#       return;
#     }
#     const dt = (await import("data:text/javascript;base64,...")).default;
#     dt(window.$);
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.8em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▲"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▼"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %%
pgm.get_available_models()
# Out:
# Xi
# r
# Gamma
# alpha
# n
# gammai
# phinull
# Xi
# r
# Gamma
# alpha
# n
# gammai
# phinull
# <style>
#     div#notebook-container    { width: 99%; }
#     div#menubar-container     { width: 65%; }
#     div#maintoolbar-container { width: 99%; }
# </style>
#                             Folder                                    Preset  \
# TUTORIAL                                                       [presetname1]
# __TEMPLATE__                                                       [preset0]
# CHIMES0                     CHIMES  [Goodwin, 2Goodwin, SimpleBi, SimpleTri]
# CESprod                 Components                                 [preset0]
# Climate_3Layers         Components                                 [default]
# Consumption_utility     Components     [preset2goods, preset3goods, presetN]
# inflationU              Components                                        []
# matterimport            Components                                 [preset0]
# GK                            Core                                 [default]
# GK_divexp                     Core                                    [test]
# Goodwin                       Core                    [default, many-orbits]
# CHIMES                    Extended  [Goodwin, 2Goodwin, SimpleBi, SimpleTri]
# GK_Endo                   Extended                                        []
# Goodwin-PiInPhi           Extended                                     [zpi]
# Goodwin_CES               Extended                                     [CES]
# Goodwin_Endo              Extended                    [default, many-orbits]
# GEMMES_Coping2018           GEMMES                [BAU, BAU_DAM, TRANSITION]
# reduced_G copy       ReducedSystem                                        []
# reduced_G            ReducedSystem                                        []
# reduced_GK           ReducedSystem                                    [Fred]
# reduced_GKCES        ReducedSystem                                 [default]
# reduced_GK_FRED      ReducedSystem                     [FredValues, Goodwin]
# reduced_GK_FRED2     ReducedSystem                     [FredValues, Goodwin]
# test0                ReducedSystem                                        []
#
#                                                    Short Documentation
# TUTORIAL             Tutorial on how to write a model. Read the file !
# __TEMPLATE__         Template to write your model. This is the shor...
# CHIMES0                        Numerical core for multisectoral models
# CESprod                         Transform production function to a CES
# Climate_3Layers      This is a 3-Layer CLimate model, that gives te...
# Consumption_utility  CHIMES Consumption module: Utility on possessions
# inflationU           CHIMES Consumption module: Utility on possessions
# matterimport         Template to write your model. This is the shor...
# GK                   Goodwin-Keen model: debt dynamics with residua...
# GK_divexp            Goodwin-Keen with diverging philips and expone...
# Goodwin                    Goodwin model: Stock-flow consistency core
# CHIMES               Extension to CHIMES: the core with alternative...
# GK_Endo                Goodwin-Keen with Endogenous technical progress
# Goodwin-PiInPhi            Goodwin with profit impacting Philips curve
# Goodwin_CES                     Goodwin with a CES production function
# Goodwin_Endo         \nDESCRIPTION :\n\n    This is a small modific...
# GEMMES_Coping2018                          GEMMES 2018 : GK + Climate
# reduced_G copy                  2-dimensional reduced Goodwin dynamics
# reduced_G                       2-dimensional reduced Goodwin dynamics
# reduced_GK                 3-dimensional reduced Goodwin-Keen dynamics
# reduced_GKCES        3-dimensional reduced Goodwin-Keen dynamics wi...
# reduced_GK_FRED         GK with affine kappa and philips, with US data
# reduced_GK_FRED2        GK with affine kappa and philips, with US data
# test0                           2-dimensional reduced Goodwin dynamics

# %%
hub=pgm.Hub('Consumption_utility')
#display(*hub.get_summary())
hub.set_dparam(**{'delta':0.1})
# Out:
# The following fields are defined in the model but not it the library :
# 	- statevar: ['utility', 'relutility', 'Cweight', 'Upkeep']
# 	- parameter: ['Z', 'H0', 'U', 'rho']
# The following fields are identified as parameters :
# 	- independant : ['delta']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : []
# 	 - state variable : ['utility']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['utility', 'relutility', 'Cweight', 'Upkeep', 'W', 'C']
# 	- differential: ['H', 'time']
#
# Changing Fields: ['delta']
# Identified delta as a value change on all axes

# %%
hub.set_dparam(**{'g':0.01})
hub.run()
hub.plot()
# Out:
# Changing Fields: ['g']
# Identified g as a value change on all axes
#
# time step 1000 / 1000
# False
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# Out:
# Collecting pyshader
#   Downloading pyshader-0.7.0-py3-none-any.whl (67 kB)
#      -------------------------------------- 67.9/67.9 kB 408.9 kB/s eta 0:00:00
# Installing collected packages: pyshader
# Successfully installed pyshader-0.7.0

# %%
hub=pgm.Hub('CHIMES0',verb=False)
hub.set_preset('SimpleBi',verb=False)
hub.run()
# Out:
# time step 658 / 1000
# time step 1000 / 1000

# %%
sectors = hub.dparam['Nprod']['list']
for sector in sectors :
    pgm.plots.plotnyaxis(hub, y=[[['inflation', sector],
                                  ['inflationMarkup', sector],
                                  ['inflationdotV', sector], ],
                                 [['dotV',sector]],
                                 [['c',sector],
                                  ['p',sector]],
                                 [['pi',sector],
                                  ['kappa',sector]],
                                 [['employment',sector],
                                  #['u',sector],
                                  ]],
                                  tini=0,
                                  tend=10)
'''
    pgm.plots.repartition(hub,
                          ['pi','omega','Mxi','Mgamma','rd','reloverinvest','reldotv'],
                          sign= [1,1,1,1,1,1,-1],
                          sector=sector,
                          title=f'Expected relative budget $\pi$ for sector {sector}',
                                  tini=0,
                                  tend=10)
    pgm.plots.repartition(hub,['Minter','Minvest','C','dotV'],
                          ref='Y',
                          sector=sector,
                          title=f'Physical Fluxes for sector {sector}',
                                  tini=0,
                                  tend=10)
    pgm.plots.repartition(hub,['MtransactY','MtransactI','wL','pC','rD'],
                          sign=[1, 1, 1, -1, 1],
                          ref='dotD',
                          sector=sector,
                          title=f'Monetary Fluxes for sector {sector}',
                          removetranspose=True,
                                  tini=0,
                                  tend=10)
'''
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# "\n    pgm.plots.repartition(hub,\n                          ['pi','omega','Mxi','Mgamma','rd','reloverinvest','reldotv'],\n                          sign= [1,1,1,1,1,1,-1],\n                          sector=sector,\n                          title=f'Expected relative budget $\\pi$ for sector {sector}',\n                                  tini=0,\n                                  tend=10)\n    pgm.plots.repartition(hub,['Minter','Minvest','C','dotV'],\n                          ref='Y',\n                          sector=sector,\n                          title=f'Physical Fluxes for sector {sector}',\n                                  tini=0,\n                                  tend=10)\n    pgm.plots.repartition(hub,['MtransactY','MtransactI','wL','pC','rD'],\n                          sign=[1, 1, 1, -1, 1],\n                          ref='dotD',\n                          sector=sector,\n                          title=f'Monetary Fluxes for sector {sector}',\n                          removetranspose=True,\n                                  tini=0,\n                                  tend=10)\n"

# %%
display(*hub.get_summary())
# Out:
#                                          definition      units  \
# Nprod                    Name of productive sectors  undefined
# D                            Debt of private sector          $
# Dh                                Debt of household          $
# V                                Inventory of Goods      Units
# K                             Capital in real units      Units
# ...                                             ...        ...
# philinConst       wage rate when full unemployement     y^{-1}
# philinSlope   wage rate dependance to unemployement     y^{-1}
# k0           GDP share investedat zeroprofit (expo)
# k1                          Investment slope (expo)
# A                            Efficiency in CES prod     y^{-1}
#
#                             source_exp com               group         symbol  \
# Nprod                                                Numerical        $Nprod$
# D                           dD/dt=dotD                    Debt            $D$
# Dh           dDh/dt=-W + O.sprod(p, C)                    Debt           $Dh$
# V                           dV/dt=dotV              Production            $V$
# K                 dK/dt=Ir - delta * K              Production            $K$
# ...                                ...  ..                 ...            ...
# philinConst                                 Salary Negociation  $philinConst$
# philinSlope                                 Salary Negociation  $philinSlope$
# k0                                                  Investment           $k0$
# k1                                                  Investment           $k1$
# A                                                   Production            $A$
#
#             isneeded                size        eqtype
# Nprod                 [__ONE__, __ONE__]          size
# D               True    [Nprod, __ONE__]  differential
# Dh              True  [__ONE__, __ONE__]  differential
# V              False    [Nprod, __ONE__]  differential
# K               True    [Nprod, __ONE__]  differential
# ...              ...                 ...           ...
# philinConst           [__ONE__, __ONE__]
# philinSlope           [__ONE__, __ONE__]
# k0                    [__ONE__, __ONE__]
# k1                    [__ONE__, __ONE__]
# A                     [__ONE__, __ONE__]
#
# [89 rows x 9 columns]
#                                field     value
# Multi1      Multi2
# Consumption                    apond       1.0
# Capital                        apond       1.0
# Consumption                   CESexp    1000.0
# Capital                       CESexp    1000.0
# Consumption                        b       3.0
# Capital                            b       3.0
#                              phinull       0.1
#                                    r      0.03
#                               gammai       0.0
# Consumption Consumption           Xi      0.01
#             Capital               Xi       1.0
# Capital     Consumption           Xi       0.1
#             Capital               Xi       1.0
# Consumption Consumption        Gamma      0.05
#             Capital            Gamma       0.0
# Capital     Consumption        Gamma       0.0
#             Capital            Gamma       0.0
#                                    n     0.025
#                                alpha      0.02
#                                 Tmax      50.0
#                                 Tini       0.0
#                                   dt       0.1
#                              __ONE__       1.0
#                                delta      0.05
# Consumption                        z       1.0
# Capital                            z       1.0
#                                  eta       0.3
# Consumption                      mu0       1.2
# Capital                          mu0       1.2
#                                  chi       1.0
# Consumption                    Cpond       1.0
# Capital                        Cpond       0.0
#                                Delta       0.0
#                          philinConst    -0.292
#                          philinSlope     0.469
#                                   k0       1.0
#                                   k1  0.006738
#                                    A  0.333333
#                  field     value
# Multi1      time
# Consumption 0.0      D       0.0
#             49.9     D       0.0
# Capital     0.0      D       NaN
#             49.9     D       NaN
#             0.0     Dh       0.0
#             49.9    Dh       NaN
# Consumption 0.0      V       1.0
#             49.9     V       1.0
# Capital     0.0      V       NaN
#             49.9     V       NaN
# Consumption 0.0      K       2.3
#             49.9     K       0.5
# Capital     0.0      K       NaN
#             49.9     K       NaN
# Consumption 0.0      p       1.0
#             49.9     p       1.0
# Capital     0.0      p       NaN
#             49.9     p       NaN
#             0.0     w0       0.6
#             49.9    w0       NaN
#             0.0     a0       1.0
#             49.9    a0  2.712851
#             0.0      N       1.0
#             49.9     N  3.481628
#             0.0   time       0.0
#             49.9  time      49.9
#                         field value
# Multi1      Multi2 time
# Consumption        0.0      w   0.6
#                    49.9     w   0.6
# Capital            0.0      w   NaN
#                    49.9     w   NaN
# Consumption        0.0      a   1.0
# ...                       ...   ...
# Capital            49.9     l   NaN
# Consumption        0.0     nu   NaN
#                    49.9    nu   NaN
# Capital            0.0     nu   NaN
#                    49.9    nu   NaN
#
# [214 rows x 2 columns]
