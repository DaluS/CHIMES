# %% [markdown]
# # Non-tracked Jupyter notebook

# %%
path = "C:\\Users\\Paul Valcke\\Documents\\GitHub\\CHIMES" 

# Importations
import sys
sys.path.insert(0, path)

# Homemade version of libraries installation
import os 
#!{sys.executable} -m pip install numpy pandas ipywidgets matplotlib plotly scipy pyvis jupyter inspect functools
#!{sys.executable} -m pip install itables ipympl pylatexenc

import chimes as chm

#### VISUALISATION
from itables import init_notebook_mode
import itables.options as opt
init_notebook_mode(all_interactive=True)

#%matplotlib widget
from IPython.display import display,HTML,Markdown
from IPython.display import IFrame

opt.columnDefs = [{"className": "dt-left", "targets": "_all"}]
opt.classes="display nowrap compact"
opt.scrollY="500px"
opt.scrollCollapse=True
opt.paging=False

import matplotlib.pyplot as plt

from pandasgui import show
# Out:
# <script type="module">
#   window.initializeDataTable = async () => {
#     if ($.prototype.DataTable) {
#       return;
#     }
#     const dt = (await import("data:text/javascript;base64,...")).default;
#     dt(window.$);
#   }
# </script>
# <style>table.dataTable td.dt-control{text-align:center;cursor:pointer}table.dataTable td.dt-control:before{height:1em;width:1em;margin-top:-9px;display:inline-block;color:white;border:.15em solid white;border-radius:1em;box-shadow:0 0 .2em #444;box-sizing:content-box;text-align:center;text-indent:0 !important;font-family:"Courier New",Courier,monospace;line-height:1em;content:"+";background-color:#31b131}table.dataTable tr.dt-hasChild td.dt-control:before{content:"-";background-color:#d33333}table.dataTable thead>tr>th.sorting,table.dataTable thead>tr>th.sorting_asc,table.dataTable thead>tr>th.sorting_desc,table.dataTable thead>tr>th.sorting_asc_disabled,table.dataTable thead>tr>th.sorting_desc_disabled,table.dataTable thead>tr>td.sorting,table.dataTable thead>tr>td.sorting_asc,table.dataTable thead>tr>td.sorting_desc,table.dataTable thead>tr>td.sorting_asc_disabled,table.dataTable thead>tr>td.sorting_desc_disabled{cursor:pointer;position:relative;padding-right:26px}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after{position:absolute;display:block;opacity:.125;right:10px;line-height:9px;font-size:.8em}table.dataTable thead>tr>th.sorting:before,table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:before,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>th.sorting_desc_disabled:before,table.dataTable thead>tr>td.sorting:before,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:before,table.dataTable thead>tr>td.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:before{bottom:50%;content:"▲"}table.dataTable thead>tr>th.sorting:after,table.dataTable thead>tr>th.sorting_asc:after,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>th.sorting_asc_disabled:after,table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting:after,table.dataTable thead>tr>td.sorting_asc:after,table.dataTable thead>tr>td.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc_disabled:after,table.dataTable thead>tr>td.sorting_desc_disabled:after{top:50%;content:"▼"}table.dataTable thead>tr>th.sorting_asc:before,table.dataTable thead>tr>th.sorting_desc:after,table.dataTable thead>tr>td.sorting_asc:before,table.dataTable thead>tr>td.sorting_desc:after{opacity:.6}table.dataTable thead>tr>th.sorting_desc_disabled:after,table.dataTable thead>tr>th.sorting_asc_disabled:before,table.dataTable thead>tr>td.sorting_desc_disabled:after,table.dataTable thead>tr>td.sorting_asc_disabled:before{display:none}table.dataTable thead>tr>th:active,table.dataTable thead>tr>td:active{outline:none}div.dataTables_scrollBody table.dataTable thead>tr>th:before,div.dataTables_scrollBody table.dataTable thead>tr>th:after,div.dataTables_scrollBody table.dataTable thead>tr>td:before,div.dataTables_scrollBody table.dataTable thead>tr>td:after{display:none}div.dataTables_processing{position:absolute;top:50%;left:50%;width:200px;margin-left:-100px;margin-top:-26px;text-align:center; ...

# %%
hub=chm.Hub('GK')
hub.get_supplements(returnas=True)
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'k2', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['d', 'g', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'inflation', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
# {'ThreeDynamics': 'Draw three qualitatively different Dynamical phase-space associated with a Goodwin-Keen'}

# %%
chm.get_available_plots()
# Out:
# <style type="text/css">
# #T_b8df1_row0_col0, #T_b8df1_row0_col1, #T_b8df1_row1_col0, #T_b8df1_row1_col1, #T_b8df1_row2_col0, #T_b8df1_row2_col1, #T_b8df1_row3_col0, #T_b8df1_row3_col1, #T_b8df1_row4_col0, #T_b8df1_row4_col1, #T_b8df1_row5_col0, #T_b8df1_row5_col1, #T_b8df1_row6_col0, #T_b8df1_row6_col1, #T_b8df1_row7_col0, #T_b8df1_row7_col1, #T_b8df1_row8_col0, #T_b8df1_row8_col1, #T_b8df1_row9_col0, #T_b8df1_row9_col1, #T_b8df1_row10_col0, #T_b8df1_row10_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_b8df1">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b8df1_level0_col0" class="col_heading level0 col0" >documentation</th>
#       <th id="T_b8df1_level0_col1" class="col_heading level0 col1" >signature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b8df1_level0_row0" class="row_heading level0 row0" >Sankey</th>
#       <td id="T_b8df1_row0_col0" class="data row0 col0" >Physical and monetary Sankey diagrams</td>
#       <td id="T_b8df1_row0_col1" class="data row0 col1" >(hub, t=0, idx=0, Region=0, figPhy=False, figMoney=False)</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row1" class="row_heading level0 row1" >Var</th>
#       <td id="T_b8df1_row1_col0" class="data row1 col0" >
#     One variable plot, with possibly cycles analysis and sensitivity if asked
#     if you put [key,sectorname] it will load the specific sector
#     if mode = 'sensitivity' the system will show statistical variance between parrallel run of nx
#     if mode = 'cycles' the system will show cycles within the evolution of the variable with their characteristics
#     </td>
#       <td id="T_b8df1_row1_col1" class="data row1 col1" >(hub, key, mode=False, log=False, idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row2" class="row_heading level0 row2" >XY</th>
#       <td id="T_b8df1_row2_col0" class="data row2 col0" >
#     plot 'x' in function of 'y', the curve color being the value of 'color'.
#     </td>
#       <td id="T_b8df1_row2_col1" class="data row2 col1" >(hub, x, y, color='time', scaled=False, idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row3" class="row_heading level0 row3" >XYZ</th>
#       <td id="T_b8df1_row3_col0" class="data row3 col0" >Plot a 3D curve, with a fourth field as the color of the curve</td>
#       <td id="T_b8df1_row3_col1" class="data row3 col1" >(hub, x, y, z, color='time', idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row4" class="row_heading level0 row4" >convergence</th>
#       <td id="T_b8df1_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_b8df1_row4_col1" class="data row4 col1" >(hub, finalpoint, showtrajectory=False)</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row5" class="row_heading level0 row5" >cycles_characteristics</th>
#       <td id="T_b8df1_row5_col0" class="data row5 col0" >
#     Plot frequency and harmonicity for each cycle found in the system
#
#     xaxis='omega',yaxis='employment',ref='employment',
#     type1 and type2 should be in ['t_mean_cycle','period_T','medval','stdval','minval','maxval','frequency','Coeffs','Harmonicity']
#     </td>
#       <td id="T_b8df1_row5_col1" class="data row5 col1" >(hub, xaxis='omega', yaxis='employment', ref='employment', type1='frequency', normalize=False, Region=0, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row6" class="row_heading level0 row6" >phasespace</th>
#       <td id="T_b8df1_row6_col0" class="data row6 col0" >
#     Depreciated, use XY instead
#     </td>
#       <td id="T_b8df1_row6_col1" class="data row6 col1" >(hub, x, y, color='time', idx=0, Region=0)</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row7" class="row_heading level0 row7" >plot3D</th>
#       <td id="T_b8df1_row7_col0" class="data row7 col0" >
#     Depreciated, use XYZ instead
#     </td>
#       <td id="T_b8df1_row7_col1" class="data row7 col1" >(hub, x, y, z, color, cmap='jet', index=0, Region=0, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row8" class="row_heading level0 row8" >plotbyunits</th>
#       <td id="T_b8df1_row8_col0" class="data row8 col0" >
#     generate one subfigure per set of units existing.
#
#     There are three layers of filters, each of them has the same logic :
#     if the filter is a tuple () it exclude the elements inside,
#     if the filter is a list [] it includes the elements inside.
#
#     Filters are the following :
#     filters_units      : select the units you want
#     filters_sector     : select the sector you want  ( '' is all monosetorial variables)
#     filters_sector     : you can put sector names if you want them or not. '' corespond to all monosectoral variables
#     separate_variables : key is a unit (y , y^{-1}... and value are keys from that units that will be shown on another graph,
#
#     Region             : is, if there a multiple regions, the one you want to plot
#     idx                : is the same for parrallel systems
#
#     separate_variable : is a dictionnary, which will create a new plot with variables fron the unit selected
#     (exemple: you have pi, epsilon and x which share the same units 'y', if you do separate_variables={'y':'x'}
#     another figure will be added with x only on it, and pi and epsilon on the other one)
#     </td>
#       <td id="T_b8df1_row8_col1" class="data row8 col1" >(hub, filters_key=(), filters_units=(), filters_sector=(), separate_variables={}, lw=1, idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row9" class="row_heading level0 row9" >plotnyaxis</th>
#       <td id="T_b8df1_row9_col0" class="data row9 col0" >
#     x must be a variable name (x axis organisation)
#     y must be a list of list of variables names (each list is a shared axis)
#
#     example :
#         pgm.plots.plotnyaxis(hub, x='time',
#                      y=[['employment', 'omega'],
#                         ['pi'],
#                         ],
#                      idx=0,
#                      title='',
#                      lw=2)
#     </td>
#       <td id="T_b8df1_row9_col1" class="data row9 col1" >(hub, y=[[]], x='time', log=False, idx=0, Region=0, tini=False, tend=False, title='', lw=2, loc='best')</td>
#     </tr>
#     <tr>
#       <th id="T_b8df1_level0_row10" class="row_heading level0 row10" >repartition</th>
#       <td id="T_b8df1_row10_col0" class="data row10 col0" >
#     Temporal visualisation of a composition.
#     Recommended use on stock-flow consistency and budget repartition.
#
#     Variables :
#     * hub
#     * keys : list of fields considered in the decomposition
#     * sector : the sector you want to verify. Monosectoral is ''
#     * sign : either '+','-' or a list of ['+','-'], to apply for each key. Must be a list of same length.
#     * ref : the reference level to compare to the components. Typically in the case of debt stock-flow, ref is dotD.
#     * title : title,
#     * idx : number of the system in parrallel
#     * region : number or id of the system considered
#     * removetranspose : if there is a matrix of transaction (from i to j), add negatively the transpose of the matrix terms
#
#     Will create a substack of the different component you put in.
#
#     Example on a multisectoral :
#     repartition(hub,['pi','rd','xi','gamma','omega'],sector='Consumption')
#     repartition(hub,['pi','rd','xi','gamma','omega'],sector='Capital')
#
#     Same as repartition, but will take matrices as inputs
#     </td>
#       <td id="T_b8df1_row10_col1" class="data row10 col1" >(hub, keys: list, sector='', sign='+', ref='', stock=False, refsign='+', removetranspose=False, title='', idx=0, Region=0, tini=False, tend=False)</td>
#     </tr>
#   </tbody>
# </table>

# %%
hub=chm.Hub('GKd')
hub.set_preset('infinity_debt')
hub.run()
hub.plot_preset()
# Out:
# The following fields are defined in the model but not it the library :
# 	- parameter: ['Agamma']
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'k2', 'A', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['g', 'C', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'solvability', 'inflation', 'Gamma', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
#
# Changing Dimensions: ['dt']
# Changing Fields: ['A', 'a', 'N', 'K', 'D', 'w', 'alpha', 'n', 'nu', 'delta', 'k0', 'k1', 'k2', 'r', 'p', 'eta']
# Changes Ignored:['gammai']
# Identified N as a value change on all axes
# Identified k2 as a value change on all axes
# Identified w as a value change on all axes
# Identified eta as a value change on all axes
# Identified alpha as a value change on all axes
# Identified D as a value change on all axes
# Identified delta as a value change on all axes
# Identified k0 as a value change on all axes
# Identified nu as a value change on all axes
# Identified p as a value change on all axes
# Identified n as a value change on all axes
# Identified A as a value change on all axes
# Identified r as a value change on all axes
# Identified a as a value change on all axes
# Identified k1 as a value change on all axes
# Identified K as a value change on all axes
#
# time step 878 / 9090
# C:\Users\Paul Valcke\Documents\GitHub\CHIMES\models\Weiye\_model_GKd.py:109: RuntimeWarning: overflow encountered in exp
#   'func': lambda A,d,nu :  np.maximum(0,1 - np.exp(A/(1-(nu/d)**2))),
# C:\Users\Paul Valcke\Documents\GitHub\CHIMES\models\Weiye\_model_GKd.py:89: RuntimeWarning: invalid value encountered in power
#   'func': lambda kappa, Y, solvability,p: p*kappa * Y * solvability**(1/4),
# time step 9090 / 9090
# plot phasespace is depreciated, use XY instead
# Depreciated, use XYZ instead

# %% [markdown]
# # Checking models quickly

# %%
chm.get_available_models()

# %%
chm.get_available_plots()
# Out:
# <style type="text/css">
# #T_14eaa_row0_col0, #T_14eaa_row0_col1, #T_14eaa_row1_col0, #T_14eaa_row1_col1, #T_14eaa_row2_col0, #T_14eaa_row2_col1, #T_14eaa_row3_col0, #T_14eaa_row3_col1, #T_14eaa_row4_col0, #T_14eaa_row4_col1, #T_14eaa_row5_col0, #T_14eaa_row5_col1, #T_14eaa_row6_col0, #T_14eaa_row6_col1, #T_14eaa_row7_col0, #T_14eaa_row7_col1, #T_14eaa_row8_col0, #T_14eaa_row8_col1, #T_14eaa_row9_col0, #T_14eaa_row9_col1, #T_14eaa_row10_col0, #T_14eaa_row10_col1 {
#   text-align: left;
# }
# </style>
# <table id="T_14eaa">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_14eaa_level0_col0" class="col_heading level0 col0" >documentation</th>
#       <th id="T_14eaa_level0_col1" class="col_heading level0 col1" >signature</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_14eaa_level0_row0" class="row_heading level0 row0" >Sankey</th>
#       <td id="T_14eaa_row0_col0" class="data row0 col0" >Physical and monetary Sankey diagrams</td>
#       <td id="T_14eaa_row0_col1" class="data row0 col1" >(hub, t=0, idx=0, Region=0, figPhy=False, figMoney=False)</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row1" class="row_heading level0 row1" >Var</th>
#       <td id="T_14eaa_row1_col0" class="data row1 col0" >
#     One variable plot, with possibly cycles analysis and sensitivity if asked
#     if you put [key,sectorname] it will load the specific sector
#     if mode = 'sensitivity' the system will show statistical variance between parrallel run of nx
#     if mode = 'cycles' the system will show cycles within the evolution of the variable with their characteristics
#     </td>
#       <td id="T_14eaa_row1_col1" class="data row1 col1" >(hub, key, mode=False, log=False, idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row2" class="row_heading level0 row2" >XY</th>
#       <td id="T_14eaa_row2_col0" class="data row2 col0" >
#     plot 'x' in function of 'y', the curve color being the value of 'color'.
#     </td>
#       <td id="T_14eaa_row2_col1" class="data row2 col1" >(hub, x, y, color='time', scaled=False, idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row3" class="row_heading level0 row3" >XYZ</th>
#       <td id="T_14eaa_row3_col0" class="data row3 col0" >Plot a 3D curve, with a fourth field as the color of the curve</td>
#       <td id="T_14eaa_row3_col1" class="data row3 col1" >(hub, x, y, z, color='time', idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row4" class="row_heading level0 row4" >convergence</th>
#       <td id="T_14eaa_row4_col0" class="data row4 col0" >None</td>
#       <td id="T_14eaa_row4_col1" class="data row4 col1" >(hub, finalpoint, showtrajectory=False)</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row5" class="row_heading level0 row5" >cycles_characteristics</th>
#       <td id="T_14eaa_row5_col0" class="data row5 col0" >
#     Plot frequency and harmonicity for each cycle found in the system
#
#     xaxis='omega',yaxis='employment',ref='employment',
#     type1 and type2 should be in ['t_mean_cycle','period_T','medval','stdval','minval','maxval','frequency','Coeffs','Harmonicity']
#     </td>
#       <td id="T_14eaa_row5_col1" class="data row5 col1" >(hub, xaxis='omega', yaxis='employment', ref='employment', type1='frequency', normalize=False, Region=0, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row6" class="row_heading level0 row6" >phasespace</th>
#       <td id="T_14eaa_row6_col0" class="data row6 col0" >
#     Depreciated, use XY instead
#     </td>
#       <td id="T_14eaa_row6_col1" class="data row6 col1" >(hub, x, y, color='time', idx=0, Region=0)</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row7" class="row_heading level0 row7" >plot3D</th>
#       <td id="T_14eaa_row7_col0" class="data row7 col0" >
#     Depreciated, use XYZ instead
#     </td>
#       <td id="T_14eaa_row7_col1" class="data row7 col1" >(hub, x, y, z, color, cmap='jet', index=0, Region=0, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row8" class="row_heading level0 row8" >plotbyunits</th>
#       <td id="T_14eaa_row8_col0" class="data row8 col0" >
#     generate one subfigure per set of units existing.
#
#     There are three layers of filters, each of them has the same logic :
#     if the filter is a tuple () it exclude the elements inside,
#     if the filter is a list [] it includes the elements inside.
#
#     Filters are the following :
#     filters_units      : select the units you want
#     filters_sector     : select the sector you want  ( '' is all monosetorial variables)
#     filters_sector     : you can put sector names if you want them or not. '' corespond to all monosectoral variables
#     separate_variables : key is a unit (y , y^{-1}... and value are keys from that units that will be shown on another graph,
#
#     Region             : is, if there a multiple regions, the one you want to plot
#     idx                : is the same for parrallel systems
#
#     separate_variable : is a dictionnary, which will create a new plot with variables fron the unit selected
#     (exemple: you have pi, epsilon and x which share the same units 'y', if you do separate_variables={'y':'x'}
#     another figure will be added with x only on it, and pi and epsilon on the other one)
#     </td>
#       <td id="T_14eaa_row8_col1" class="data row8 col1" >(hub, filters_key=(), filters_units=(), filters_sector=(), separate_variables={}, lw=1, idx=0, Region=0, tini=False, tend=False, title='')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row9" class="row_heading level0 row9" >plotnyaxis</th>
#       <td id="T_14eaa_row9_col0" class="data row9 col0" >
#     x must be a variable name (x axis organisation)
#     y must be a list of list of variables names (each list is a shared axis)
#
#     example :
#         pgm.plots.plotnyaxis(hub, x='time',
#                      y=[['employment', 'omega'],
#                         ['pi'],
#                         ],
#                      idx=0,
#                      title='',
#                      lw=2)
#     </td>
#       <td id="T_14eaa_row9_col1" class="data row9 col1" >(hub, y=[[]], x='time', log=False, idx=0, Region=0, tini=False, tend=False, title='', lw=2, loc='best')</td>
#     </tr>
#     <tr>
#       <th id="T_14eaa_level0_row10" class="row_heading level0 row10" >repartition</th>
#       <td id="T_14eaa_row10_col0" class="data row10 col0" >
#     Temporal visualisation of a composition.
#     Recommended use on stock-flow consistency and budget repartition.
#
#     Variables :
#     * hub
#     * keys : list of fields considered in the decomposition
#     * sector : the sector you want to verify. Monosectoral is ''
#     * sign : either '+','-' or a list of ['+','-'], to apply for each key. Must be a list of same length.
#     * ref : the reference level to compare to the components. Typically in the case of debt stock-flow, ref is dotD.
#     * title : title,
#     * idx : number of the system in parrallel
#     * region : number or id of the system considered
#     * removetranspose : if there is a matrix of transaction (from i to j), add negatively the transpose of the matrix terms
#
#     Will create a substack of the different component you put in.
#
#     Example on a multisectoral :
#     repartition(hub,['pi','rd','xi','gamma','omega'],sector='Consumption')
#     repartition(hub,['pi','rd','xi','gamma','omega'],sector='Capital')
#
#     Same as repartition, but will take matrices as inputs
#     </td>
#       <td id="T_14eaa_row10_col1" class="data row10 col1" >(hub, keys: list, sector='', sign='+', ref='', stock=False, refsign='+', removetranspose=False, title='', idx=0, Region=0, tini=False, tend=False)</td>
#     </tr>
#   </tbody>
# </table>

# %%
hub=chm.Hub('GK')
hub.supplements['ThreeDynamics'](hub)
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'k2', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['d', 'g', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'inflation', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
plt.close('all')

hub=chm.Hub('Goodwin',preset='default')
hub.run()
hub.plot()
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'nu', 'philinConst', 'philinSlope']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : ['pi', 'omega', 'g', 'C']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Y', 'L', 'omega', 'employment', 'Pi', 'Ir', 'phillips', 'pi', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'time']
#
# time step 3 / 1000
# time step 1000 / 1000
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
hub=chm.Hub('Goodwin','default')
hub.run()
hub.plot_preset()
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'nu', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : ['pi', 'omega', 'g', 'C']
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['Y', 'L', 'omega', 'employment', 'Pi', 'Ir', 'phillips', 'pi', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'time']
#
# time step 1000 / 1000

# %%
chm.get_available_models()
# Out:
# IMPORT MIGHT HAVE ISSUES
# IMPORT MIGHT HAVE ISSUES
#                                             Folder  \
# CHI                                           Core
# GK                                            Core
# Goodwin                                       Core
# Climate_3Layers                             Gemmes
# GEMMES_Coping2018                           Gemmes
# DampOscillator                       Miscellaneous
# stochastic                           Miscellaneous
# _EXTERNALCOUPLING_Matter             Miscellaneous
# Agents_Vicsek                 Miscellaneous\Agents
# DoublePendulum            Miscellaneous\Attractors
# LorenzSystem              Miscellaneous\Attractors
# PDE-Diffusion                              Spatial
# PDE-Diffusion2D                            Spatial
# PDE-Waves                                  Spatial
#
#                                                                      Preset  \
# CHI                                                               [default]
# GK                                 [default, debtcrisis, debtstabilisation]
# Goodwin                                              [default, many-orbits]
# Climate_3Layers                                                   [default]
# GEMMES_Coping2018                                [BAU, BAU_DAM, TRANSITION]
# DampOscillator            [Perfect Oscillations, FirstOrder, Overdamp, C...
# stochastic                                                     [Onevar, 10]
# _EXTERNALCOUPLING_Matter                                          [preset0]
# Agents_Vicsek                          [synchronisation, TooNoisy, LowSync]
# DoublePendulum                                                    [default]
# LorenzSystem                                            [Canonical example]
# PDE-Diffusion                                                       [Basic]
# PDE-Diffusion2D                                                     [Basic]
# PDE-Waves                                                           [Basic]
#
#                                                         Short Documentation
# CHI                                  Human-Capital Instability: Causal core
# GK                        Goodwin-Keen model: debt dynamics with residua...
# Goodwin                         Goodwin model: Stock-flow consistency core
# Climate_3Layers           This is a 3-Layer CLimate model, that gives te...
# GEMMES_Coping2018                               GEMMES 2018 : GK + Climate
# DampOscillator            \nDESCRIPTION : Just the description of a seco...
# stochastic                                             Stochastic dynamics
# _EXTERNALCOUPLING_Matter  Template to write your model. This is the shor...
# Agents_Vicsek                                      Movement synchronization
# DoublePendulum                     Double Uniform Pendulum Chaotic Dynamics
# LorenzSystem                    Lorenz Chaotic Attractor: Butterfly effect!
# PDE-Diffusion                                         1D Diffusion in space
# PDE-Diffusion2D           \nA simple 1D diffusion :\n\nthe system solves...
# PDE-Waves                 Wave propagation with convection and diffusion...

# %%
hub=chm.Hub('PDE-Waves',preset='Basic')
hub.run()
hub.supplements['Plot'](hub)
# Out:
# The following fields are defined in the model but not it the library :
# 	- differential: ['dC']
# 	- statevar: ['d2C', 'gradCx', 'lapC']
# 	- parameter: ['x', 'diffCoeff', 'v', 'nabla']
# The following fields are identified as parameters :
# 	- independant : []
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : []
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['gradCx', 'lapC', 'd2C']
# 	- differential: ['dC', 'C', 'time']
#
# time step 10000 / 10000

# %%
hub.get_supplements(returnas=dict)
# Out:
# {'Plot': 'Plot time-slices of the concentration (horizontal time, vertical spatial). \n    First concentration, second time variation, third gradient, fourth laplacian',
#  'Generate': 'Generate all parameters for the simulation'}

# %%
hub=chm.Hub('ECHIMES')
# Out:
# The following fields are defined in the model but not it the library :
# 	- statevar: ['v', 'MGammaY', 'MIrXi', 'employmentAgg']
# 	- parameter: ['DeltaB', 'epsinV', 'rho']
# The following fields are identified as parameters :
# 	- independant : ['k0']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : ['employment', 'MGammaY', 'MIrXi', 'rd', 'ROC']
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['w', 'u', 'Y', 'v', 'Mgamma', 'Mxi', 'MGammaY', 'MtransactY', 'rD', 'rDh', 'rd', 'a', 'L', 'employment', 'omega', 'c', 'inflationMarkup', 'wL', 'employmentAgg', 'Phillips', 'pi', 'ROC', 'Sh', 'kappa', 'I', 'MtransactI', 'W', 'Ir', 'C', 'dotV', 'MIrXi', 'pC', 'dotD', 'inflationdotV', 'basket', 'inflation', 'ibasket']
# 	- differential: ['D', 'Dh', 'V', 'K', 'p', 'w0', 'u0', 'a0', 'N', 'time']

# %%
hub?
# Out:
# Model       : ECHIMES
#
# ECONOMIC CORE for HOLISTIC INTERDISCIPLINARY MODEL assessing ECOLOGICAL SUSTAINABILITY
#
# The goal of CHIMES is :
#     * description of production with physical variables
#     * behavior of agents (price, investment) based on economic values
#     * Connexion to ecological systems through physical coupling (emissions, land use...)
#
# It integrates :
#     * N productive sector, by activity
#     * Material flow analysis integrated inside
#     * Loans dynamics for investment and cross-sector expanses
#     * Inventory fluctuations
#     * Inflation
#     * Adaptive use of capital
#
# File        : C:\Users\Paul Valcke\Documents\GitHub\CHIMES\models\Core\_model_ECHIMES.py
# ####################       Fields       ####################
# statevar        037 ['w', 'u', 'Y', 'v', 'Mgamma', 'Mxi', 'MGammaY', 'MtransactY', 'rD', 'rDh', 'rd', 'a', 'L', 'employment', 'omega', 'c', 'inflationMarkup', 'wL', 'employmentAgg', 'Phillips', 'pi', 'ROC', 'Sh', 'kappa', 'I', 'MtransactI', 'W', 'Ir', 'C', 'dotV', 'MIrXi', 'pC', 'dotD', 'inflationdotV', 'basket', 'inflation', 'ibasket']
# differential    010 ['D', 'Dh', 'V', 'K', 'p', 'w0', 'u0', 'a0', 'N', 'time']
# parameters      033 ['k0', 'phi0', 'phi1', 'Nprod', 'nu', 'alpha', 'n', 'phinull', 'r', 'z', 'b', 'nu0', 'Cpond', 'mu0', 'DeltaB', 'delta', 'deltah', 'sigma', 'divlinconst', 'divlinSlope', 'gammai', 'eta', 'chi', 'epsinV', 'Gamma', 'Xi', 'rho']
# ####################      Presets       ####################
#           Goodwin       : A monosectoral system that behaves just as a Goodwin
#          Bisectoral     : Two sectors : one producing consumption good, one for capital goods.Converging run starting for VERY far from equilibrium
#           SimpleBi      : Two sectors : one producing consumption good, one for capital goods.Converging run starting close to equilibrium
#          SimpleTri      : Trisectoral
#           SimpleN       : Two sectors : one producing consumption good, one for capital goods.Converging run starting close to equilibrium
# ####################       Flags        ####################
# run            : False
# cycles         : False
# derivative     : False
# multisectoral  : True
# solver         :
# ####################    Time vector     ####################
# Tmax                100                 Total simulated time
# Tini                0                   Initial time for simulations
# dt                  0.1                 solver timestep
# nt                  1000                Number of timestep
# ####################     Dimensions     ####################
# Nprod               1                   Name of productive sectors
# nx                  1                   Number of system in parrallel
# nr                  1                   Number of regions interconnected
# Model       : ECHIMES
#
# ECONOMIC CORE for HOLISTIC INTERDISCIPLINARY MODEL assessing ECOLOGICAL SUSTAINABILITY
#
# The goal of CHIMES is :
#     * description of production with physical variables
#     * behavior of agents (price, investment) based on economic values
#     * Connexion to ecological systems through physical coupling (emissions, land use...)
#
# It integrates :
#     * N productive sector, by activity
#     * Material flow analysis integrated inside
#     * Loans dynamics for investment and cross-sector expanses
#     * Inventory fluctuations
#     * Inflation
#     * Adaptive use of capital
#
# File        : C:\Users\Paul Valcke\Documents\GitHub\CHIMES\models\Core\_model_ECHIMES.py
# ####################       Fields       ####################
# statevar        037 ['w', 'u', 'Y', 'v', 'Mgamma', 'Mxi', 'MGammaY', 'MtransactY', 'rD', 'rDh', 'rd', 'a', 'L', 'employment', 'omega', 'c', 'inflationMarkup', 'wL', 'employmentAgg', 'Phillips', 'pi', 'ROC', 'Sh', 'kappa', 'I', 'MtransactI', 'W', 'Ir', 'C', 'dotV', 'MIrXi', 'pC', 'dotD', 'inflationdotV', 'basket', 'inflation', 'ibasket']
# differential    010 ['D', 'Dh', 'V', 'K', 'p', 'w0', 'u0', 'a0', 'N', 'time']
# parameters      033 ['k0', 'phi0', 'phi1', 'Nprod', 'nu', 'alpha', 'n', 'phinull', 'r', 'z', 'b', 'nu0', 'Cpond', 'mu0', 'DeltaB', 'delta', 'deltah', 'sigma', 'divlinconst', 'divlinSlope', 'gammai', 'eta', 'chi', 'epsinV', 'Gamma', 'Xi', 'rho']
# ####################      Presets       ####################
#           Goodwin       : A monosectoral system that behaves just as a Goodwin
#          Bisectoral     : Two sectors : one producing consumption good, one for capital goods.Converging run starting for VERY far from equilibrium
#           SimpleBi      : Two sectors : one producing consumption good, one for capital goods.Converging run starting close to equilibrium
#          SimpleTri      : Trisectoral
#           SimpleN       : Two sectors : one producing consumption good, one for capital goods.Converging run starting close to equilibrium
# ####################       Flags        ####################
# run            : False
# cycles         : False
# derivative     : False
# multisectoral  : True
# solver         :
# ####################    Time vector     ####################
# Tmax                100                 Total simulated time
# Tini                0                   Initial time for simulations
# dt                  0.1                 solver timestep
# nt                  1000                Number of timestep
# ####################     Dimensions     ####################
# Nprod               1                   Name of productive sectors
# nx                  1                   Number of system in parrallel
# nr                  1                   Number of regions interconnected
# Type:        Hub
# String form:
# File:        c:\users\paul valcke\documents\github\CHIMES\chimes\_core.py
# Docstring:
# MOST IMPORTANT OBJECT FOR THE USER.
# given a model name, it will load it and get its logics, presets and associated values.
# It will :
#     * identify what are the parameters, the state variables, the differential variables
#     * find their associated properties (definition, units, values)
#     * find an order of calculation
#
# You then access to fields value modification, the structure and properties in the model,
# simulation, plots, deeper analysis...
#
# INPUTS :
# * model : STRING containing the model name
# * from_user : [Desactivated] BOOLEAN if you want to use your file (True) or the one provided in chimes (False)
# * preset : DICTIONNARY name of the preset in the actual dictionnary of preset
# * dpreset : DICTOFDICTOFDIC a dictionnary of preset one can use (see model creation)
# * verb : BOOLEAN True for print in terminal
#
# model files are named _model_<model-name>.py
#
# A number of pre-defined models are available from the library,
#     see pgm.get_available_models() to get a list

# %%
hub.set_preset('SimpleTri')
# Out:
# Changing Dimensions: ['Tmax', 'Nprod']
# Changing Fields: ['alpha', 'n', 'phinull', 'gammai', 'r', 'N', 'Dh', 'sigma', 'K', 'D', 'p', 'V', 'z', 'k0', 'Cpond', 'mu0', 'delta', 'deltah', 'eta', 'chi', 'b', 'nu', 'Gamma', 'Xi', 'rho']
# Changes Ignored:['a', 'w', 'u', 'dt', 'nx']
# Now Nprod has 3 sectors with names ['Consumption', 'Intermediate', 'Capital']
# Identified deltah as a value change on all axes
# Identified nu as a value change on all axes
# Identified chi as a value change on all axes
# Identified gammai as a value change on all axes
# Identified r as a value change on all axes
# Identified b as a value change on all axes
# Identified Dh as a value change on all axes
# Identified delta as a value change on all axes
# Identified N as a value change on all axes
# Identified alpha as a value change on all axes
# Identified z as a value change on all axes
# Identified eta as a value change on all axes
# Identified phinull as a value change on all axes
# Identified n as a value change on all axes
# Identified mu0 as a value change on all axes
# Identified k0 as a value change on all axes

# %%
hub.run()

# %%
hub.plot_preset()

# %%
hub=chm.Hub('reduced_G_stochastic')
hub.run()
hub.plot()
# Out:
# The following fields are defined in the model but not it the library :
# 	- differential: ['noisecumulate']
# 	- statevar: ['newalpha']
# 	- parameter: ['noise']
# The following fields are identified as parameters :
# 	- independant : ['beta', 'delta', 'nu', 'alpha', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['noisecumulate', 'time']
# 	 - state variable : []
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['phillips', 'newalpha']
# 	- differential: ['employment', 'omega', 'noisecumulate', 'time']
#
# time step 1000 / 1000

# %%
lpreset
# Out:
# {'00equilibrium': 'Start close to the (0,0) equilibrium',
#  'NontrivialEQ': 'Start almostat the non-trivial equilibrium',
#  'farfromEQ': 'Start far from EQ'}

# %%
chm.get_available_models()
# Out:
# IMPORTMODEL MIGHT HAVE ISSUES, BE CAREFUL
# IMPORTMODEL MIGHT HAVE ISSUES, BE CAREFUL
#                                             Folder  \
# CHI                                           Core
# GK                                            Core
# Goodwin                                       Core
# Climate_3Layers                             Gemmes
# GEMMES_Coping2018                           Gemmes
# DampOscillator                       Miscellaneous
# stochastic                           Miscellaneous
# _EXTERNALCOUPLING_Matter             Miscellaneous
# Agents_Vicsek                 Miscellaneous\Agents
# DoublePendulum            Miscellaneous\Attractors
# LorenzSystem              Miscellaneous\Attractors
# reduced_G                            ReducedSystem
# Reduced_GK                           ReducedSystem
# reduced_GKCES                        ReducedSystem
# reduced_GK_FRED2                     ReducedSystem
# reduced_G_stochastic                 ReducedSystem
# PDE-Diffusion                              Spatial
# PDE-Waves                                  Spatial
#
#                                                                      Preset  \
# CHI                                                               [default]
# GK                                 [default, debtcrisis, debtstabilisation]
# Goodwin                                              [default, many-orbits]
# Climate_3Layers                                                   [default]
# GEMMES_Coping2018                                [BAU, BAU_DAM, TRANSITION]
# DampOscillator            [Perfect Oscillations, FirstOrder, Overdamp, C...
# stochastic                                                     [Onevar, 10]
# _EXTERNALCOUPLING_Matter                                          [preset0]
# Agents_Vicsek                          [synchronisation, TooNoisy, LowSync]
# DoublePendulum                                                    [default]
# LorenzSystem                                            [Canonical example]
# reduced_G                          [00equilibrium, NontrivialEQ, farfromEQ]
# Reduced_GK                                                        [default]
# reduced_GKCES                                                     [default]
# reduced_GK_FRED2                                      [FredValues, Goodwin]
# reduced_G_stochastic                                                     []
# PDE-Diffusion                                                       [Basic]
# PDE-Waves                                                           [Basic]
#
#                                                         Short Documentation
# CHI                                  Human-Capital Instability: Causal core
# GK                        Goodwin-Keen model: debt dynamics with residua...
# Goodwin                         Goodwin model: Stock-flow consistency core
# Climate_3Layers           This is a 3-Layer CLimate model, that gives te...
# GEMMES_Coping2018                               GEMMES 2018 : GK + Climate
# DampOscillator            \nDESCRIPTION : Just the description of a seco...
# stochastic                                             Stochastic dynamics
# _EXTERNALCOUPLING_Matter  Template to write your model. This is the shor...
# Agents_Vicsek                                      Movement synchronization
# DoublePendulum                     Double Uniform Pendulum Chaotic Dynamics
# LorenzSystem                    Lorenz Chaotic Attractor: Butterfly effect!
# reduced_G                            2-dimensional reduced Goodwin dynamics
# Reduced_GK                \nABSTRACT: This is a 3 sector model : bank, h...
# reduced_GKCES             3-dimensional reduced Goodwin-Keen dynamics wi...
# reduced_GK_FRED2             GK with affine kappa and philips, with US data
# reduced_G_stochastic        Goodwin system with noise on technical progress
# PDE-Diffusion                                         1D Diffusion in space
# PDE-Waves                 Wave propagation with convection and diffusion...

# %%
hub=chm.Hub('reduced_GKCES')
hub.run()
hub.plot_preset('default')
# Out:
# The following fields are defined in the model but not it the library :
# 	- statevar: ['dotomega']
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'CESexp', 'r', 'delta', 'k0', 'k1', 'k2', 'A', 'b', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : []
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['phillips', 'pi', 'kappa', 'nu', 'dotomega', 'g']
# 	- differential: ['employment', 'omega', 'd', 'time']
#
# time step 1000 / 1000

# %%
for FULL in [False,True]:
    for Return in [dict,list,False]: 
        out = chm.get_available_models(FULL=FULL,Return=Return)

for model in chm.get_available_models(Return=list):
    for returnString in [True,False]:
        chm.get_model_documentation(model,returnString=returnString)

chm.get_available_fields(exploreModels=True)
chm.get_available_fields(exploreModels=False)

chm.get_available_plots()

chm.get_available_functions()

chm.get_available_operators()

# %%
for FULL in [False,True]:
    for Return in [dict,list,False]: 
        out = chm.get_available_models(FULL=FULL,Return=Return)

# %%
for model in chm.get_available_models(Return=list):
    for returnString in [True,False]:
        chm.get_model_documentation(model,returnString=returnString)

# %%
# Out:
# The following fields are defined in the model but not it the library :
# The following fields are identified as parameters :
# 	- independant : ['alpha', 'n', 'delta', 'r', 'nu', 'eta', 'mu', 'k0', 'k1', 'k2', 'phinull']
# 	- function of other parameters : ['phi0', 'phi1']
# The following variables are identified as auxilliary :
# 	 - differential : ['Dh', 'time']
# 	 - state variable : ['d', 'g', 'GDP']
# The following order has been determined for functions:
# 	- parameter: ['nt', 'phi0', 'phi1']
# 	- statevar: ['Y', 'L', 'GDP', 'd', 'omega', 'employment', 'c', 'Pi', 'inflation', 'phillips', 'pi', 'kappa', 'I', 'Ir', 'g', 'C']
# 	- differential: ['a', 'N', 'K', 'w', 'p', 'D', 'Dh', 'time']
