# %% [markdown]
# * **Goal of the day:** Prepare plots for a presentation, centered around linear endogenisations
# * **Coder:** Paul Valcke

# %%
import sys
sys.path.insert(0,  "../../" )
import chimes as chm
import numpy as np 
import matplotlib.pyplot as plt

import plotly.graph_objects as go
import numpy as np

# %%
hub=chm.Hub('Lotka_Goodwin')
hub.set_fields(x=0.51,x0=.51,y0=.49,y=0.49,dt=0.01,Tsim=3)

# %%
hub.run()
chm.Plots.XY(hub,'x0','y0')
# Out:
# time step 300 / 300
