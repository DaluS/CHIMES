# %%
import sys
sys.path.insert(0,  "../../../" )
import chimes as chm

# %%
hub=chm.Hub('Metzlerian')
# Out:
# The following fields are defined in the model but not it the library :
# 	- differential: ['Xe']
# 	- statevar: ['Vd', 'Jd', 'v', 'X', 'hu', 'eu']
# 	- parameter: ['ustar', 'lambbda', 'betae', 'betah']
# The following fields are identified as parameters :
# 	- independant : ['a', 'c']
# 	- function of other parameters : []
# The following variables are identified as auxilliary :
# 	 - differential : ['time']
# 	 - state variable : ['I', 'z', 'v', 'u', 'hu', 'eu']
# The following order has been determined for functions:
# 	- parameter: ['nt']
# 	- statevar: ['Vd', 'Jd', 'Y', 'z', 'v', 'u', 'X', 'hu', 'eu', 'I']
# 	- differential: ['V', 'Xe', 'K', 'time']

# %%
hub.get_summary()
# Out:
# ############################################################
# ####################      SUMMARY       ####################
# ############################################################
# Model       : Metzlerian
# A Metzlerian model of inventory growth cycles
# File        : c:\Users\Paul Valcke\Documents\GitHub\CHIMES\notebooks\Paul\Daily\../../..\models\MiscEco\_model_Metzlerian.py
# #################### Fields ####################
# statevar        010 ['Vd', 'Jd', 'Y', 'z', 'v', 'u', 'X', 'hu', 'eu', 'I']
# differential    004 ['V', 'Xe', 'K', 'time']
# parameters      010 ['a', 'c', 'mu', 'ustar', 'lambbda', 'g', 'sigma', 'betae', 'betah', 'Nprod']
# #################### Presets ####################
# #################### Flags ####################
# run            : [0, 0]
# cycles         : False
# sensitivity    : False
# derivative     : False
# convergence    : False
# multisectoral  : False
# multiregional  : False
# Parrallel      : False
# reinterpolated : False
# ...

# %%
hub.run()
# Out:
# time step 1000 / 1000
# time step 1000 / 1000

# %%
hub.plot()
